# %% [markdown]
# ## Lesson 1

# %% [markdown]
# 1\. Create the program that writes to a file the multiplication table for pairs of integers from 2 to 9. The content of the file should be like<br>
# `2 x 2 = 4`<br>
# `2 x 3 = 6`<br>
# `...`<br>
# `9 x 8 = 72`<br>
# `9 x 9 = 81`<br>

# %%
text = ""
for i in range(2, 10):
    for j in range(2, 10):
        text = text + f"{i} x {j} = {i * j}\n"

# %%
textfile = '08_HW_Lesson1.txt'


with open(textfile, 'w') as file:
    file.write(text)

# %%
# !cat 08_HW_Lesson1.txt
# Out:
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64
# 8 x 9 = 72
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81

# %% [markdown]
# 4\. Create a program that writes to a CSV-file a table with two columns. The first one is the month name and the second one is the number of its days.

# %%
# !pip install calendra python-csv
# Out:
# ...
#   Using cached python-csv-0.0.13.tar.gz (26 kB)
# ...
#   Using cached leven-1.0.4.tar.gz (20 kB)
# ...
#   Using cached xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# ...
#   Using cached xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# ...
#   ERROR: Command errored out with exit status 1:
#    command: /home/usr/hse/magolego/venv/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-r1ovkfbv/python-csv/setup.py'"'"'; __file__='"'"'/tmp/pip-install-r1ovkfbv/python-csv/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-_wwfwtp7
#        cwd: /tmp/pip-install-r1ovkfbv/python-csv/
#   Complete output (6 lines):
#   usage: setup.py [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#      or: setup.py --help [cmd1 cmd2 ...]
#      or: setup.py --help-commands
#      or: setup.py cmd --help
#
# ...

# %%
import calendar
import csv

# %%
with open('08_HW_Lesson1.csv', 'w') as file:
    writer = csv.writer(file, delimiter=',')
    for d in range(12): 
        writer.writerow(
            [calendar.month_name[d+1],
             calendar.monthrange(2023, d+1)[1]])

# %%
# !cat 08_HW_Lesson1.csv
# Out:
# January,31
# February,28
# March,31
# April,30
# May,31
# June,30
# July,31
# August,31
# September,30
# October,31
# November,30
# December,31

# %% [markdown]
# ## Lesson 2

# %% [markdown]
# 5\. Write the program the loads webpage https://kupav.github.io/data-sc-intro/dickens.html and find there a link to a wikipedia article about Charles Dickens.

# %%
# !pip install requests bs4 html5lib lxml

# %%
import requests
url = "https://kupav.github.io/data-sc-intro/dickens.html"
raw_data = requests.get(url)
assert raw_data.status_code == 200

# %%
import bs4
soup = bs4.BeautifulSoup(raw_data.text, 'html5lib')
all_h2 = soup.find_all('p')
interesting = []
for i in all_h2:
    if "wikipedia" in str(i):
        interesting.append(i)

# %%
for i in interesting:
    if "Charles" in str(i):
        print(i)
# Out:
# <p>
#     <a href="https://en.wikipedia.org/wiki/Charles_Dickens">See Charles
#       Dickens in Wikipedia</a></p>

# %% [markdown]
# 6\. Find some news portal you like. Write the program that loads its main page and saves its full textual content to a file.

# %%
# This module downloads webpages
import requests

# This is an URL of a webpage 
url = "https://habr.com/ru/company/selectel/blog/721022/"

# Here we downlaod the file
raw_data = requests.get(url)

# Check if downlaing was successfull
assert raw_data.status_code == 200

# This module converts raw data downloaded by request into a readable structure
from bs4 import BeautifulSoup

# Now we parse convert it to readable structure. HTML parsing is done via library 'html5lib'
soup = BeautifulSoup(raw_data.text, 'html5lib')
textfile = 'habr_text.txt'

soup_string = str(soup.text)
with open(textfile, 'w', encoding="utf-8") as file:
    file.write(soup_string)

# %%
# !cat habr_text.txt
# Out:
#
#
#
#   Как разработать канбан-доску на Django, DRF и Alpine.js / Хабр
#
#     /* cyrillic-ext */
#     @font-face {
#       font-family: 'Fira Sans';
#       font-style: normal;
#       font-weight: 500;
#       font-display: swap;
#       src: url(https://fonts.gstatic.com/s/firasans/v11/va9B4kDNxMZdWfMOD5VnZKveSxf6TF0.woff2) format('woff2');
#       unicode-range: U+0460-052F, U+1C80-1C88, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F;
#     }
#
#     /* cyrillic */
#     @font-face {
#       font-family: 'Fira Sans';
#       font-style: normal;
#       font-weight: 500;
#       font-display: swap;
#       src: url(https://fonts.gstatic.com/s/firasans/v11/va9B4kDNxMZdWfMOD5VnZKveQhf6TF0.woff2) format('woff2');
#       unicode-range: U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116;
#     }
#
#     /* latin-ext */
#     @font-face {
#       font-family: 'Fira Sans';
#       font-style: normal;
#       font-weight: 500;
#       font-display: swap;
# ...
